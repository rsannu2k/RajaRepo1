# %%
import pyspark
from pyspark.sql import SparkSession
import json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Spark Session initialization
spark = SparkSession.builder.enableHiveSupport().getOrCreate()

#Connection_Properties read from json
config = {}
with open("/dbfs/FileStore/xle_policy/connection.json", "r") as f:
  config = json.load(f)

conn_xl_edw_dw_xle_r32_FilePath = config.get("conn_xl_edw_dw_xle_r32_FilePath")
conn_xl_edw_hash_xle_r32_FilePath = config.get("conn_xl_edw_hash_xle_r32_FilePath")
conn_xl_edw_warehouseadmin_xle_r32_FilePath = config.get("conn_xl_edw_warehouseadmin_xle_r32_FilePath")
conn_xl_edw_interface_xle_r32_FilePath = config.get("conn_xl_edw_interface_xle_r32_FilePath")
conn_xl_edw_hash_xle_r32_Type = config.get("conn_xl_edw_hash_xle_r32_Type")
conn_xl_edw_warehouseadmin_xle_r32_Type = config.get("conn_xl_edw_warehouseadmin_xle_r32_Type")
conn_Source_FilePath = config.get("conn_Source_FilePath")
conn__FilePath = config.get("conn__FilePath")
conn_Source_Type = config.get("conn_Source_Type")
conn__Type = config.get("conn__Type")
conn_Target_FilePath = config.get("conn_Target_FilePath")
conn_xl_edw_interface_xle_r32_Type = config.get("conn_xl_edw_interface_xle_r32_Type")




mapVariable_DEFAULT_CONF_CD = config.get("mapVariable_DEFAULT_CONF_CD")
mapVariable_SUM_RI_CONT_CVRG_LIM_ATTCH_PNT_ORIG_AMT = config.get("mapVariable_SUM_RI_CONT_CVRG_LIM_ATTCH_PNT_ORIG_AMT")
mapVariable_V_SUM_CAPTD_TRANS_AMT_ORIG = config.get("mapVariable_V_SUM_CAPTD_TRANS_AMT_ORIG")
mapVariable_WF_Name = config.get("mapVariable_WF_Name")
mapVariable_V_SUM_CACPTD_TRANS_AMT_RWOFF = config.get("mapVariable_V_SUM_CACPTD_TRANS_AMT_RWOFF")
mapVariable_SUM_RITD_AGG_LIMIT_ORIG_AMT = config.get("mapVariable_SUM_RITD_AGG_LIMIT_ORIG_AMT")
mapVariable_ceded_comm_amt = config.get("mapVariable_ceded_comm_amt")
mapVariable_SERVER_NME_STG = config.get("mapVariable_SERVER_NME_STG")
mapVariable_BAL_RULE1 = config.get("mapVariable_BAL_RULE1")
mapVariable_V_COUNT_CACPTD_ORIG_RWOFF = config.get("mapVariable_V_COUNT_CACPTD_ORIG_RWOFF")
mapVariable_ceded_epr_amt = config.get("mapVariable_ceded_epr_amt")
mapVariable_DBConnection_STG = config.get("mapVariable_DBConnection_STG")
mapVariable_ceded_paid_loss_amt = config.get("mapVariable_ceded_paid_loss_amt")
mapVariable_DEFAULT_DATE = config.get("mapVariable_DEFAULT_DATE")
mapVariable_ACCTNG_LYR_CD_DUMMY = config.get("mapVariable_ACCTNG_LYR_CD_DUMMY")
mapVariable_DBNME_TGT = config.get("mapVariable_DBNME_TGT")
mapVariable_BAL_RULE2 = config.get("mapVariable_BAL_RULE2")
mapVariable_ACCT_LAYER_CD_IN = config.get("mapVariable_ACCT_LAYER_CD_IN")
mapVariable_V_SUM_CAPTD_TRANS_AMT_RWOFF = config.get("mapVariable_V_SUM_CAPTD_TRANS_AMT_RWOFF")
mapVariable_gross_epr_amt = config.get("mapVariable_gross_epr_amt")
mapVariable_WAREHOUSE_DB = config.get("mapVariable_WAREHOUSE_DB")
mapVariable_V_SUM_CACPTD_TRANS_AMT_WOFF = config.get("mapVariable_V_SUM_CACPTD_TRANS_AMT_WOFF")
mapVariable_net_incurred_loss_amt = config.get("mapVariable_net_incurred_loss_amt")
mapVariable_V_COUNT_CAPTD_ORIG_ORIG = config.get("mapVariable_V_COUNT_CAPTD_ORIG_ORIG")
mapVariable_BATCH_SET_STS_IND = config.get("mapVariable_BATCH_SET_STS_IND")
mapVariable_SUM_plcy_cvrg_ded_sir_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_ded_sir_orig_amt")
mapVariable_net_comm_amt = config.get("mapVariable_net_comm_amt")
mapVariable_V_SUM_CACPTD_ORIG_AMT_RORIG_RFXCV = config.get("mapVariable_V_SUM_CACPTD_ORIG_AMT_RORIG_RFXCV")
mapVariable_V_SUM_CAPTD_ORIG_AMT_ORIG = config.get("mapVariable_V_SUM_CAPTD_ORIG_AMT_ORIG")
mapVariable_MAX_BATCH_ID = config.get("mapVariable_MAX_BATCH_ID")
mapVariable_TGT_COLUMN = config.get("mapVariable_TGT_COLUMN")
mapVariable_SUM_plcy_cvrg_ded_agg_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_ded_agg_orig_amt")
mapVariable_deductible_amt = config.get("mapVariable_deductible_amt")
mapVariable_STATUS_IND = config.get("mapVariable_STATUS_IND")
mapVariable_SRC_COUNT = config.get("mapVariable_SRC_COUNT")
mapVariable_LEDGER_ID_FIL = config.get("mapVariable_LEDGER_ID_FIL")
mapVariable_net_epr_amt = config.get("mapVariable_net_epr_amt")
mapVariable_V_SUM_CAPTD_TRANS_AMT_RFXCV = config.get("mapVariable_V_SUM_CAPTD_TRANS_AMT_RFXCV")
mapVariable_V_SUM_CACPTD_ORIG_AMT_RORIG = config.get("mapVariable_V_SUM_CACPTD_ORIG_AMT_RORIG")
mapVariable_V_TRANS_AMT = config.get("mapVariable_V_TRANS_AMT")
mapVariable_SUM_RITD_EST_SUM_PRM_WHOLE_AMT = config.get("mapVariable_SUM_RITD_EST_SUM_PRM_WHOLE_AMT")
mapVariable_PRELOAD_IND = config.get("mapVariable_PRELOAD_IND")
mapVariable_V_COUNT_CACPTD_ORIG_RORIG = config.get("mapVariable_V_COUNT_CACPTD_ORIG_RORIG")
mapVariable_BATCH_STS_IND = config.get("mapVariable_BATCH_STS_IND")
mapVariable_XRI_FILTER = config.get("mapVariable_XRI_FILTER")
mapVariable_TGT_TBL_HDR = config.get("mapVariable_TGT_TBL_HDR")
mapVariable_FACT_IND = config.get("mapVariable_FACT_IND")
mapVariable_TBL_OWNER_AUDIT = config.get("mapVariable_TBL_OWNER_AUDIT")
mapVariable_ORIG_AMT = config.get("mapVariable_ORIG_AMT")
mapVariable_SERVER_NME_BUILD = config.get("mapVariable_SERVER_NME_BUILD")
mapVariable_SUM_plcy_cvrg_prm_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_prm_orig_amt")
mapVariable_TBL_FCT_N_HASH = config.get("mapVariable_TBL_FCT_N_HASH")
mapVariable_SUM_RITD_AGG_DED_ORIG_AMT = config.get("mapVariable_SUM_RITD_AGG_DED_ORIG_AMT")
mapVariable_DB_SRC = config.get("mapVariable_DB_SRC")
mapVariable_ceded_paid_alae_amt = config.get("mapVariable_ceded_paid_alae_amt")
mapVariable_V_COUNT_CACPTD_ORIG_FXCV = config.get("mapVariable_V_COUNT_CACPTD_ORIG_FXCV")
mapVariable_INT_HASH_PROC = config.get("mapVariable_INT_HASH_PROC")
mapVariable_SUM_plcy_cvrg_ded_pcn_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_ded_pcn_orig_amt")
mapVariable_V_SUM_CACPTD_ORIG_AMT_ORIG = config.get("mapVariable_V_SUM_CACPTD_ORIG_AMT_ORIG")
mapVariable_gross_written_prm_amt = config.get("mapVariable_gross_written_prm_amt")
mapVariable_V_SUM_CACPTD_TRANS_AMT_RORIG = config.get("mapVariable_V_SUM_CACPTD_TRANS_AMT_RORIG")
mapVariable_ceded_incurred_alae_amt = config.get("mapVariable_ceded_incurred_alae_amt")
mapVariable_PREV_TRANS_END = config.get("mapVariable_PREV_TRANS_END")
mapVariable_V_LAST_TRANS_END = config.get("mapVariable_V_LAST_TRANS_END")
mapVariable_SUM_plcy_cvrg_lim_agg_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_lim_agg_orig_amt")
mapVariable_dbnme_wrkr = config.get("mapVariable_dbnme_wrkr")
mapVariable_TRUNC_IND = config.get("mapVariable_TRUNC_IND")
mapVariable_V_COUNT_CACPTD_RORIG_RFXCV = config.get("mapVariable_V_COUNT_CACPTD_RORIG_RFXCV")
mapVariable_TBL_OWNER_HASH = config.get("mapVariable_TBL_OWNER_HASH")
mapVariable_V_SUM_CAPTD_ORIG_AMT_RORIG = config.get("mapVariable_V_SUM_CAPTD_ORIG_AMT_RORIG")
mapVariable_V_COUNT_CAPTD_ORIG_RORIG = config.get("mapVariable_V_COUNT_CAPTD_ORIG_RORIG")
mapVariable_INT_DIM = config.get("mapVariable_INT_DIM")
mapVariable_V_SUM_CACPTD_TRANS_AMT_FXCV = config.get("mapVariable_V_SUM_CACPTD_TRANS_AMT_FXCV")
mapVariable_V_SUM_CACPTD_TRANS_AMT_RORIG_RFXCV = config.get("mapVariable_V_SUM_CACPTD_TRANS_AMT_RORIG_RFXCV")
mapVariable_net_paid_alae_amt = config.get("mapVariable_net_paid_alae_amt")
mapVariable_tbl_owner_stg = config.get("mapVariable_tbl_owner_stg")
mapVariable_gross_incurred_alae_amt = config.get("mapVariable_gross_incurred_alae_amt")
mapVariable_SRC_SYS_NAME = config.get("mapVariable_SRC_SYS_NAME")
mapVariable_gross_comm_amt = config.get("mapVariable_gross_comm_amt")
mapVariable_V_SUM_CAPTD_ORIG_AMT_RWOFF = config.get("mapVariable_V_SUM_CAPTD_ORIG_AMT_RWOFF")
mapVariable_V_ORIG_AMT = config.get("mapVariable_V_ORIG_AMT")
mapVariable_V_SUM_CACTD_TRANS_AMT = config.get("mapVariable_V_SUM_CACTD_TRANS_AMT")
mapVariable_SUM_plcy_cvrg_ded_min_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_ded_min_orig_amt")
mapVariable_SUM_plcy_cvrg_lim_attch_pnt_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_lim_attch_pnt_orig_amt")
mapVariable_DBNME_INT = config.get("mapVariable_DBNME_INT")
mapVariable_V_CURR_BATCH_ID = config.get("mapVariable_V_CURR_BATCH_ID")
mapVariable_TBL_DIM_C_HASH = config.get("mapVariable_TBL_DIM_C_HASH")
mapVariable_V_SUM_CACPTD_ORIG_AMT_WOFF = config.get("mapVariable_V_SUM_CACPTD_ORIG_AMT_WOFF")
mapVariable_SUM_RI_CONT_AGG_DED_ERODED_AMT = config.get("mapVariable_SUM_RI_CONT_AGG_DED_ERODED_AMT")
mapVariable_SUM_RI_CONT_CVRG_LIM_AGG_ORIG_AMT = config.get("mapVariable_SUM_RI_CONT_CVRG_LIM_AGG_ORIG_AMT")
mapVariable_TRANS_AMT = config.get("mapVariable_TRANS_AMT")
mapVariable_V_COUNT_CAPTD_ORIG_WOFF = config.get("mapVariable_V_COUNT_CAPTD_ORIG_WOFF")
mapVariable_DBNME_SRC = config.get("mapVariable_DBNME_SRC")
mapVariable_V_SUM_CAPTD_ORIG_AMT_FXCV = config.get("mapVariable_V_SUM_CAPTD_ORIG_AMT_FXCV")
mapVariable_SET_BATCH = config.get("mapVariable_SET_BATCH")
mapVariable_ceded_incurred_loss_amt = config.get("mapVariable_ceded_incurred_loss_amt")
mapVariable_TBL_DIM_N_HASH = config.get("mapVariable_TBL_DIM_N_HASH")
mapVariable_V_COUNT_CACPTD_ORIG_WOFF = config.get("mapVariable_V_COUNT_CACPTD_ORIG_WOFF")
mapVariable_TBL_OWNER_EDW = config.get("mapVariable_TBL_OWNER_EDW")
mapVariable_gross_paid_loss_amt = config.get("mapVariable_gross_paid_loss_amt")
mapVariable_V_SUM_CAPTD_TRANS_AMT_WOFF = config.get("mapVariable_V_SUM_CAPTD_TRANS_AMT_WOFF")
mapVariable_V_COUNT_CAPTD_ORIG_FXCV = config.get("mapVariable_V_COUNT_CAPTD_ORIG_FXCV")
mapVariable_SQL_TBL1 = config.get("mapVariable_SQL_TBL1")
mapVariable_SQL_TBL2 = config.get("mapVariable_SQL_TBL2")
mapVariable_SQL_TBL3 = config.get("mapVariable_SQL_TBL3")
mapVariable_net_incurred_alae_amt = config.get("mapVariable_net_incurred_alae_amt")
mapVariable_SQL_TBL4 = config.get("mapVariable_SQL_TBL4")
mapVariable_TBL_DIM_P_HASH = config.get("mapVariable_TBL_DIM_P_HASH")
mapVariable_t_wrker_plcy_cvrg_gp = config.get("mapVariable_t_wrker_plcy_cvrg_gp")
mapVariable_net_earned_comm_amt = config.get("mapVariable_net_earned_comm_amt")
mapVariable_V_SUM_CAPTD_TRANS_AMT_FXCV = config.get("mapVariable_V_SUM_CAPTD_TRANS_AMT_FXCV")
mapVariable_V_SUM_CJTD_ORIG_AMT = config.get("mapVariable_V_SUM_CJTD_ORIG_AMT")
mapVariable_ceded_written_prm_amt = config.get("mapVariable_ceded_written_prm_amt")
mapVariable_net_written_prm_amt = config.get("mapVariable_net_written_prm_amt")
mapVariable_ceded_earned_comm_amt = config.get("mapVariable_ceded_earned_comm_amt")
mapVariable_gross_paid_alae_amt = config.get("mapVariable_gross_paid_alae_amt")
mapVariable_PARTITION_FUNC = config.get("mapVariable_PARTITION_FUNC")
mapVariable_V_SUM_CAPTD_TRANS_AMT_RORIG = config.get("mapVariable_V_SUM_CAPTD_TRANS_AMT_RORIG")
mapVariable_SUM_plcy_cvrg_lim_occ_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_lim_occ_orig_amt")
mapVariable_V_SUM_CACPTD_ORIG_AMT_RFXCV = config.get("mapVariable_V_SUM_CACPTD_ORIG_AMT_RFXCV")
mapVariable_gross_incurred_loss_amt = config.get("mapVariable_gross_incurred_loss_amt")
mapVariable_gross_earned_comm_amt = config.get("mapVariable_gross_earned_comm_amt")
mapVariable_BAL_RULE_KEY = config.get("mapVariable_BAL_RULE_KEY")
mapVariable_SUM_RI_CONT_CVRG_PRM_ORIG_AMT = config.get("mapVariable_SUM_RI_CONT_CVRG_PRM_ORIG_AMT")
mapVariable_SUM_RI_CONT_CVRG_EST_PRM_AMT = config.get("mapVariable_SUM_RI_CONT_CVRG_EST_PRM_AMT")
mapVariable_SRC_SYS_CD = config.get("mapVariable_SRC_SYS_CD")
mapVariable_net_paid_loss_amt = config.get("mapVariable_net_paid_loss_amt")
mapVariable_V_SUM_CAPTD_ORIG_AMT_WOFF = config.get("mapVariable_V_SUM_CAPTD_ORIG_AMT_WOFF")
mapVariable_SRC_TBL_PART = config.get("mapVariable_SRC_TBL_PART")
mapVariable_V_SUM_CJTD_TRANS_AMT = config.get("mapVariable_V_SUM_CJTD_TRANS_AMT")
mapVariable_TBL_OWNER = config.get("mapVariable_TBL_OWNER")
mapVariable_V_SUM_CACTD_ORIG_AMT = config.get("mapVariable_V_SUM_CACTD_ORIG_AMT")
mapVariable_BATCH_ID = config.get("mapVariable_BATCH_ID")
mapVariable_V_SUM_CACPTD_TRANS_AMT_RFXCV = config.get("mapVariable_V_SUM_CACPTD_TRANS_AMT_RFXCV")
mapVariable_DB_TGT = config.get("mapVariable_DB_TGT")
mapVariable_DBNME_HASH = config.get("mapVariable_DBNME_HASH")
mapVariable_V_COUNT_CAPTD_ORIG_RWOFF = config.get("mapVariable_V_COUNT_CAPTD_ORIG_RWOFF")
mapVariable_AUTOSYS_JOB = config.get("mapVariable_AUTOSYS_JOB")
mapVariable_DEFAULT_START_DATE = config.get("mapVariable_DEFAULT_START_DATE")
mapVariable_V_COUNT_CACPTD_ORIG_ORIG = config.get("mapVariable_V_COUNT_CACPTD_ORIG_ORIG")
mapVariable_V_CREAT_TIME_STMP = config.get("mapVariable_V_CREAT_TIME_STMP")
mapVariable_TGT_TBL = config.get("mapVariable_TGT_TBL")
mapVariable_SUM_RI_CONT_CVRG_LIM_OCC_ORIG_AMT = config.get("mapVariable_SUM_RI_CONT_CVRG_LIM_OCC_ORIG_AMT")
mapVariable_SUM_RI_CONT_CVRG_EST_SUBJ_PRM_AMT = config.get("mapVariable_SUM_RI_CONT_CVRG_EST_SUBJ_PRM_AMT")
mapVariable_TARGET_TABLE_NAME = config.get("mapVariable_TARGET_TABLE_NAME")
mapVariable_DBNME_WA = config.get("mapVariable_DBNME_WA")
mapVariable_TBL_OWNER_BATCH = config.get("mapVariable_TBL_OWNER_BATCH")
mapVariable_V_SUM_CACPTD_ORIG_AMT_RWOFF = config.get("mapVariable_V_SUM_CACPTD_ORIG_AMT_RWOFF")
mapVariable_V_SUM_CACPTD_TRANS_AMT_ORIG = config.get("mapVariable_V_SUM_CACPTD_TRANS_AMT_ORIG")
mapVariable_TBL_OWNER_INT = config.get("mapVariable_TBL_OWNER_INT")
mapVariable_WF_NAME = config.get("mapVariable_WF_NAME")
mapVariable_TBL_OWNER_XLE = config.get("mapVariable_TBL_OWNER_XLE")
mapVariable_SUM_RITD_EST_PRM_ORDER_AMT = config.get("mapVariable_SUM_RITD_EST_PRM_ORDER_AMT")
mapVariable_TGT_TBL_PHASH = config.get("mapVariable_TGT_TBL_PHASH")
mapVariable_PARTITION_KEY = config.get("mapVariable_PARTITION_KEY")
mapVariable_SUM_plcy_cvrg_ded_max_orig_amt = config.get("mapVariable_SUM_plcy_cvrg_ded_max_orig_amt")
mapVariable_V_SUM_CACPTD_ORIG_AMT_FXCV = config.get("mapVariable_V_SUM_CACPTD_ORIG_AMT_FXCV")
mapVariable_TGT_TBL_PHASH_HDR = config.get("mapVariable_TGT_TBL_PHASH_HDR")
mapVariable_TBL_FCT_C_HASH = config.get("mapVariable_TBL_FCT_C_HASH")
mapVariable_V_COUNT_CACPTD_ORIG_RFXCV = config.get("mapVariable_V_COUNT_CACPTD_ORIG_RFXCV")
mapVariable_V_SUM_CAPTD_ORIG_AMT_RFXCV = config.get("mapVariable_V_SUM_CAPTD_ORIG_AMT_RFXCV")
mapVariable_V_COUNT_CAPTD_ORIG_RFXCV = config.get("mapVariable_V_COUNT_CAPTD_ORIG_RFXCV")
mapVariable_V_COUNT_DATA = config.get("mapVariable_V_COUNT_DATA")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
